# %%
# Import the random module

import random

# %%
# Generate a random floating-point decimal between 0 and 1
random.random()
# Out:
# 0.4215530267003713

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# -5.307954365300066

# %%
# Assign the variable x to 1.
x = 1
# Start an empty list
latitudes = []
# While loop generate random latitudes and adds to list
while x < 11:
    # after adding random lat to list, add one to variable x as long as less than 11
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
# Import the NumPy module
import numpy as np

# %%
# %timeit np.random.uniform(-90.000, 90.000, size = 1500)
# Out:
# 16.8 µs ± 540 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# Import timeit
import timeit

# %%
# Compare time of while function to np code for random numbers
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.7 ms ± 252 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# ushuaia ar
# lakatoro vu
# nishihara jp
# hermanus za
# illoqqortoormiut gl
# vaini to
# atuona pf
# pevek ru
# mbandaka cd
# punta arenas cl
# oistins bb
# upernavik gl
# illoqqortoormiut gl
# provideniya ru
# avarua ck
# viligili mv
# husavik is
# ancud cl
# constitucion mx
# sinnamary gf
# ikungi tz
# ushuaia ar
# labuhan id
# saint-philippe re
# kapaa us
# taolanaro mg
# busselton au
# mataura pf
# mlonggo id
# atuona pf
# bambous virieux mu
# rikitea pf
# rikitea pf
# hilo us
# punta arenas cl
# naze jp
# ushuaia ar
# tuktoyaktuk ca
# araouane ml
# rikitea pf
# clyde river ca
# provideniya ru
# burnie au
# atuona pf
# clyde river ca
# jiutai cn
# ponta do sol cv
# srivardhan in
# bluff nz
# hobart au
# new norfolk au
# tuatapere nz
# castro cl
# luebo cd
# magadan ru
# hermanus za
# kodiak us
# hami cn
# husavik is
# barentsburg sj
# barentsburg sj
# saint-philippe re
# saint george bm
# saskylakh ru
# abu zabad sd
# hilo us
# baykit ru
# yashkul ru
# jasper ca
# sassandra ci
# ...

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630
