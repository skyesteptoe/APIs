# %%
# Import dependencies
import requests
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the API key.
from config import open_weather

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + open_weather

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Create an empty list to hold the weather data.
city_dataredo = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']

        
        # Append the city information into city_data list.
        city_dataredo.append({"City": city_city,
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Retrieval is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | busselton
# Processing Record 2 of Set 16 | fonte boa
# Processing Record 3 of Set 16 | matagami
# Processing Record 4 of Set 16 | zaoyang
# Processing Record 5 of Set 16 | rikitea
# Processing Record 6 of Set 16 | kapaa
# Processing Record 7 of Set 16 | butaritari
# Processing Record 8 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 16 | ilinogorsk
# City not found. Skipping...
# Processing Record 10 of Set 16 | roma
# Processing Record 11 of Set 16 | clyde river
# Processing Record 12 of Set 16 | bredasdorp
# Processing Record 13 of Set 16 | punta arenas
# Processing Record 14 of Set 16 | abu dhabi
# Processing Record 15 of Set 16 | saldanha
# Processing Record 16 of Set 16 | ushuaia
# Processing Record 17 of Set 16 | jamestown
# Processing Record 18 of Set 16 | salalah
# Processing Record 19 of Set 16 | margate
# Processing Record 20 of Set 16 | genhe
# Processing Record 21 of Set 16 | beringovskiy
# Processing Record 22 of Set 16 | geraldton
# Processing Record 23 of Set 16 | mataura
# Processing Record 24 of Set 16 | albany
# Processing Record 25 of Set 16 | ribeira grande
# Processing Record 26 of Set 16 | inirida
# Processing Record 27 of Set 16 | jijiga
# Processing Record 28 of Set 16 | cape town
# Processing Record 29 of Set 16 | oistins
# Processing Record 30 of Set 16 | hamilton
# Processing Record 31 of Set 16 | tuktoyaktuk
# Processing Record 32 of Set 16 | lata
# Processing Record 33 of Set 16 | constitucion
# Processing Record 34 of Set 16 | hermanus
# Processing Record 35 of Set 16 | carnarvon
# Processing Record 36 of Set 16 | flagstaff
# Processing Record 37 of Set 16 | atuona
# Processing Record 38 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 16 | nola
# Processing Record 40 of Set 16 | port alfred
# Processing Record 41 of Set 16 | trairi
# Processing Record 42 of Set 16 | bengkulu
# Processing Record 43 of Set 16 | khani
# Processing Record 44 of Set 16 | veraval
# Processing Record 45 of Set 16 | coquimbo
# Processing Record 46 of Set 16 | eenhana
# Processing Record 47 of Set 16 | ponta do sol
# Processing Record 48 of Set 16 | korla
# Processing Record 49 of Set 16 | bluff
# Processing Record 50 of Set 16 | wewak
# Processing Record 1 of Set 17 | barrow
# Processing Record 2 of Set 17 | tautira
# Processing Record 3 of Set 17 | kloulklubed
# Processing Record 4 of Set 17 | port hedland
# Processing Record 5 of Set 17 | hobart
# Processing Record 6 of Set 17 | muros
# Processing Record 7 of Set 17 | bilma
# Processing Record 8 of Set 17 | arkadak
# Processing Record 9 of Set 17 | codrington
# Processing Record 10 of Set 17 | jiuquan
# Processing Record 11 of Set 17 | souillac
# Processing Record 12 of Set 17 | hilo
# Processing Record 13 of Set 17 | tongchuan
# Processing Record 14 of Set 17 | sitka
# Processing Record 15 of Set 17 | ahipara
# Processing Record 16 of Set 17 | imeni poliny osipenko
# Processing Record 17 of Set 17 | bardiyah
# Processing Record 18 of Set 17 | nawabganj
# Processing Record 19 of Set 17 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 17 | palmer
# Processing Record 21 of Set 17 | san carlos de bariloche
# Processing Record 22 of Set 17 | dombarovskiy
# Processing Record 23 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 17 | xiuyan
# Processing Record 25 of Set 17 | mumford
# Processing Record 26 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 17 | mecca
# Processing Record 28 of Set 17 | narsaq
# Processing Record 29 of Set 17 | bandarbeyla
# Processing Record 30 of Set 17 | puerto ayora
# Processing Record 31 of Set 17 | sao sebastiao
# Processing Record 32 of Set 17 | rio gallegos
# Processing Record 33 of Set 17 | pacific grove
# Processing Record 34 of Set 17 | port blair
# Processing Record 35 of Set 17 | pevek
# Processing Record 36 of Set 17 | vaini
# Processing Record 37 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 17 | sibay
# Processing Record 39 of Set 17 | kodiak
# Processing Record 40 of Set 17 | nikolskoye
# Processing Record 41 of Set 17 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 17 | kushima
# Processing Record 43 of Set 17 | half moon bay
# Processing Record 44 of Set 17 | cidreira
# Processing Record 45 of Set 17 | lompoc
# Processing Record 46 of Set 17 | sonoita
# Processing Record 47 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 17 | tecoanapa
# Processing Record 50 of Set 17 | norman wells
# Processing Record 1 of Set 18 | rafsanjan
# Processing Record 2 of Set 18 | connersville
# Processing Record 3 of Set 18 | novobirilyussy
# Processing Record 4 of Set 18 | richard toll
# City not found. Skipping...
# Processing Record 5 of Set 18 | quatre cocos
# Processing Record 6 of Set 18 | eureka
# Processing Record 7 of Set 18 | tommot
# Processing Record 8 of Set 18 | canyon lake
# Processing Record 9 of Set 18 | hualmay
# Processing Record 10 of Set 18 | tiksi
# Processing Record 11 of Set 18 | sao joao da barra
# Processing Record 12 of Set 18 | east london
# Processing Record 13 of Set 18 | atambua
# Processing Record 14 of Set 18 | gimli
# Processing Record 15 of Set 18 | sola
# Processing Record 16 of Set 18 | vanavara
# Processing Record 17 of Set 18 | dunedin
# Processing Record 18 of Set 18 | kaitangata
# Processing Record 19 of Set 18 | mangalam
# Processing Record 20 of Set 18 | bereda
# Processing Record 21 of Set 18 | georgetown
# Processing Record 22 of Set 18 | longyearbyen
# Processing Record 23 of Set 18 | kavaratti
# Processing Record 24 of Set 18 | tasiilaq
# Processing Record 25 of Set 18 | airai
# Processing Record 26 of Set 18 | tokur
# Processing Record 27 of Set 18 | castro
# Processing Record 28 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 18 | yellowknife
# Processing Record 30 of Set 18 | shitanjing
# Processing Record 31 of Set 18 | marv dasht
# City not found. Skipping...
# Processing Record 32 of Set 18 | kirakira
# Processing Record 33 of Set 18 | saint-philippe
# Processing Record 34 of Set 18 | qaanaaq
# Processing Record 35 of Set 18 | ancud
# Processing Record 36 of Set 18 | le port
# Processing Record 37 of Set 18 | atar
# Processing Record 38 of Set 18 | hobyo
# Processing Record 39 of Set 18 | khatanga
# Processing Record 40 of Set 18 | chuy
# Processing Record 41 of Set 18 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 18 | bay roberts
# Processing Record 43 of Set 18 | boende
# Processing Record 44 of Set 18 | mar del plata
# Processing Record 45 of Set 18 | san jeronimo
# Processing Record 46 of Set 18 | mahanoro
# Processing Record 47 of Set 18 | bethel
# Processing Record 48 of Set 18 | esperance
# Processing Record 49 of Set 18 | leningradskiy
# Processing Record 50 of Set 18 | esmeraldas
# Processing Record 1 of Set 19 | severo-kurilsk
# Processing Record 2 of Set 19 | fairbanks
# Processing Record 3 of Set 19 | iglesias
# Processing Record 4 of Set 19 | saint-francois
# Processing Record 5 of Set 19 | divnomorskoye
# Processing Record 6 of Set 19 | muroto
# Processing Record 7 of Set 19 | san cristobal
# Processing Record 8 of Set 19 | zhigansk
# Processing Record 9 of Set 19 | belle fourche
# Processing Record 10 of Set 19 | arraial do cabo
# Processing Record 11 of Set 19 | pisco
# Processing Record 12 of Set 19 | tha bo
# Processing Record 13 of Set 19 | srednekolymsk
# Processing Record 14 of Set 19 | hithadhoo
# Processing Record 15 of Set 19 | bulgan
# Processing Record 16 of Set 19 | new norfolk
# Processing Record 17 of Set 19 | oranjemund
# Processing Record 18 of Set 19 | saskylakh
# Processing Record 19 of Set 19 | visby
# Processing Record 20 of Set 19 | lebu
# Processing Record 21 of Set 19 | ambilobe
# Processing Record 22 of Set 19 | kovdor
# Processing Record 23 of Set 19 | namibe
# Processing Record 24 of Set 19 | bemidji
# Processing Record 25 of Set 19 | nizwa
# Processing Record 26 of Set 19 | victoria
# Processing Record 27 of Set 19 | pochutla
# Processing Record 28 of Set 19 | te anau
# Processing Record 29 of Set 19 | zapadnaya dvina
# Processing Record 30 of Set 19 | luderitz
# Processing Record 31 of Set 19 | lavrentiya
# Processing Record 32 of Set 19 | kieta
# Processing Record 33 of Set 19 | balsas
# Processing Record 34 of Set 19 | smoky lake
# Processing Record 35 of Set 19 | alice springs
# Processing Record 36 of Set 19 | yinchuan
# Processing Record 37 of Set 19 | bathsheba
# Processing Record 38 of Set 19 | ariquemes
# Processing Record 39 of Set 19 | mao
# Processing Record 40 of Set 19 | waddan
# Processing Record 41 of Set 19 | faanui
# Processing Record 42 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 19 | turiacu
# Processing Record 44 of Set 19 | red bluff
# Processing Record 45 of Set 19 | lagoa
# Processing Record 46 of Set 19 | jiexiu
# Processing Record 47 of Set 19 | dalby
# Processing Record 48 of Set 19 | provideniya
# Processing Record 49 of Set 19 | zhezkazgan
# Processing Record 50 of Set 19 | grande riviere du nord
# Processing Record 1 of Set 20 | charters towers
# Processing Record 2 of Set 20 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 20 | ipixuna
# Processing Record 4 of Set 20 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 20 | sunrise manor
# Processing Record 6 of Set 20 | baltasi
# Processing Record 7 of Set 20 | camaqua
# Processing Record 8 of Set 20 | chabahar
# Processing Record 9 of Set 20 | the valley
# Processing Record 10 of Set 20 | torbay
# Processing Record 11 of Set 20 | yar-sale
# Processing Record 12 of Set 20 | sovetskiy
# Processing Record 13 of Set 20 | jojoima
# Processing Record 14 of Set 20 | puerto baquerizo moreno
# Processing Record 15 of Set 20 | mount gambier
# Processing Record 16 of Set 20 | lerwick
# Processing Record 17 of Set 20 | huarmey
# Processing Record 18 of Set 20 | saint-pierre
# Processing Record 19 of Set 20 | port elizabeth
# Processing Record 20 of Set 20 | vreed en hoop
# City not found. Skipping...
# Processing Record 21 of Set 20 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 20 | malim
# Processing Record 23 of Set 20 | uthal
# Processing Record 24 of Set 20 | saint george
# Processing Record 25 of Set 20 | dukat
# Processing Record 26 of Set 20 | grindavik
# Processing Record 27 of Set 20 | bonthe
# Processing Record 28 of Set 20 | bambous virieux
# Processing Record 29 of Set 20 | mataram
# Processing Record 30 of Set 20 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 20 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 20 | predivinsk
# Processing Record 33 of Set 20 | velasco ibarra
# Processing Record 34 of Set 20 | parabel
# Processing Record 35 of Set 20 | mahebourg
# Processing Record 36 of Set 20 | hendek
# Processing Record 37 of Set 20 | vega de alatorre
# Processing Record 38 of Set 20 | guerrero negro
# Processing Record 39 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 20 | isangel
# Processing Record 41 of Set 20 | rio das pedras
# Processing Record 42 of Set 20 | avera
# Processing Record 43 of Set 20 | cap malheureux
# Processing Record 44 of Set 20 | grand gaube
# Processing Record 45 of Set 20 | halifax
# Processing Record 46 of Set 20 | port lincoln
# Processing Record 47 of Set 20 | inderborskiy
# City not found. Skipping...
# Processing Record 48 of Set 20 | tessalit
# Processing Record 49 of Set 20 | wakkanai
# Processing Record 50 of Set 20 | lahij
# Processing Record 1 of Set 21 | senanga
# Processing Record 2 of Set 21 | vlakhokerasea
# City not found. Skipping...
# Processing Record 3 of Set 21 | nabire
# Processing Record 4 of Set 21 | prince rupert
# Processing Record 5 of Set 21 | haines junction
# Processing Record 6 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 21 | iqaluit
# Processing Record 8 of Set 21 | chokurdakh
# Processing Record 9 of Set 21 | mazamari
# Processing Record 10 of Set 21 | brasilia de minas
# Processing Record 11 of Set 21 | baykit
# Processing Record 12 of Set 21 | santo antonio do ica
# Processing Record 13 of Set 21 | abengourou
# Processing Record 14 of Set 21 | talnakh
# Processing Record 15 of Set 21 | hofn
# Processing Record 16 of Set 21 | astorga
# Processing Record 17 of Set 21 | great yarmouth
# Processing Record 18 of Set 21 | sibolga
# Processing Record 19 of Set 21 | walvis bay
# Processing Record 20 of Set 21 | thunder bay
# Processing Record 21 of Set 21 | abha
# Processing Record 22 of Set 21 | choya
# Processing Record 23 of Set 21 | le vauclin
# Processing Record 24 of Set 21 | charyshskoye
# Processing Record 25 of Set 21 | ambon
# Processing Record 26 of Set 21 | kaoma
# Processing Record 27 of Set 21 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 21 | hasaki
# Processing Record 29 of Set 21 | ganzhou
# Processing Record 30 of Set 21 | garowe
# Processing Record 31 of Set 21 | faya
# Processing Record 32 of Set 21 | kodinsk
# Processing Record 33 of Set 21 | belyy yar
# Processing Record 34 of Set 21 | shache
# Processing Record 35 of Set 21 | aykhal
# Processing Record 36 of Set 21 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 21 | bambanglipuro
# Processing Record 38 of Set 21 | abnub
# Processing Record 39 of Set 21 | klaksvik
# Processing Record 40 of Set 21 | asfi
# Processing Record 41 of Set 21 | nichinan
# Processing Record 42 of Set 21 | hirara
# Processing Record 43 of Set 21 | ozernovskiy
# Processing Record 44 of Set 21 | almenara
# Processing Record 45 of Set 21 | kurilsk
# Processing Record 46 of Set 21 | belmonte
# Processing Record 47 of Set 21 | washington
# Processing Record 48 of Set 21 | auki
# Processing Record 49 of Set 21 | puerto maldonado
# Processing Record 50 of Set 21 | katsuura
# Processing Record 1 of Set 22 | acarau
# Processing Record 2 of Set 22 | coihaique
# Processing Record 3 of Set 22 | upernavik
# Processing Record 4 of Set 22 | vredendal
# Processing Record 5 of Set 22 | victor harbor
# Processing Record 6 of Set 22 | marsa matruh
# Processing Record 7 of Set 22 | horqueta
# Processing Record 8 of Set 22 | naryan-mar
# Processing Record 9 of Set 22 | avarua
# Processing Record 10 of Set 22 | areia branca
# Processing Record 11 of Set 22 | cherskiy
# Processing Record 12 of Set 22 | asau
# Processing Record 13 of Set 22 | illapel
# Processing Record 14 of Set 22 | sattahip
# Processing Record 15 of Set 22 | dehloran
# Processing Record 16 of Set 22 | kavieng
# Processing Record 17 of Set 22 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 22 | vao
# Processing Record 19 of Set 22 | dikson
# Processing Record 20 of Set 22 | najran
# Processing Record 21 of Set 22 | tigil
# Processing Record 22 of Set 22 | mehamn
# Processing Record 23 of Set 22 | san policarpo
# Processing Record 24 of Set 22 | flin flon
# Processing Record 25 of Set 22 | yaan
# Processing Record 26 of Set 22 | goderich
# Processing Record 27 of Set 22 | anadyr
# Processing Record 28 of Set 22 | shama
# Processing Record 29 of Set 22 | itarema
# Processing Record 30 of Set 22 | sinop
# Processing Record 31 of Set 22 | thompson
# Processing Record 32 of Set 22 | gopalpur
# Processing Record 33 of Set 22 | grimshaw
# Processing Record 34 of Set 22 | sabaudia
# Processing Record 35 of Set 22 | camacha
# Processing Record 36 of Set 22 | ixtapa
# Processing Record 37 of Set 22 | floro
# Processing Record 38 of Set 22 | kardymovo
# Processing Record 39 of Set 22 | amahai
# Processing Record 40 of Set 22 | whitehorse
# Processing Record 41 of Set 22 | aklavik
# Processing Record 42 of Set 22 | ballina
# Processing Record 43 of Set 22 | ust-koksa
# Processing Record 44 of Set 22 | kibara
# Processing Record 45 of Set 22 | kefamenanu
# Processing Record 46 of Set 22 | tuatapere
# Processing Record 47 of Set 22 | camacari
# Processing Record 48 of Set 22 | nurota
# Processing Record 49 of Set 22 | chernyshevskiy
# Processing Record 50 of Set 22 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 23 | xining
# Processing Record 2 of Set 23 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 23 | karratha
# Processing Record 4 of Set 23 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 23 | roccastrada
# Processing Record 6 of Set 23 | acapulco
# Processing Record 7 of Set 23 | zambezi
# Processing Record 8 of Set 23 | la ronge
# Processing Record 9 of Set 23 | bilibino
# Processing Record 10 of Set 23 | skibbereen
# Processing Record 11 of Set 23 | buraydah
# Processing Record 12 of Set 23 | hambantota
# Processing Record 13 of Set 23 | marawi
# Processing Record 14 of Set 23 | creston
# Processing Record 15 of Set 23 | sinnar
# Processing Record 16 of Set 23 | pangnirtung
# Processing Record 17 of Set 23 | andrews
# Processing Record 18 of Set 23 | hatillo
# Processing Record 19 of Set 23 | dunda
# Processing Record 20 of Set 23 | nanma
# Processing Record 21 of Set 23 | yulara
# Processing Record 22 of Set 23 | cobija
# Processing Record 23 of Set 23 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 23 | murud
# Processing Record 25 of Set 23 | tomohon
# Processing Record 26 of Set 23 | havoysund
# Processing Record 27 of Set 23 | miri
# Processing Record 28 of Set 23 | cabo san lucas
# Processing Record 29 of Set 23 | shipley
# Processing Record 30 of Set 23 | kota bahru
# Processing Record 31 of Set 23 | izhma
# Processing Record 32 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 23 | kumla
# Processing Record 34 of Set 23 | bairiki
# Processing Record 35 of Set 23 | ostrovnoy
# Processing Record 36 of Set 23 | priladozhskiy
# Processing Record 37 of Set 23 | padang
# Processing Record 38 of Set 23 | garwolin
# Processing Record 39 of Set 23 | nam tha
# City not found. Skipping...
# Processing Record 40 of Set 23 | adrar
# Processing Record 41 of Set 23 | ilulissat
# Processing Record 42 of Set 23 | kidal
# Processing Record 43 of Set 23 | usinsk
# Processing Record 44 of Set 23 | kondinskoye
# Processing Record 45 of Set 23 | kamyaran
# Processing Record 46 of Set 23 | poptun
# Processing Record 47 of Set 23 | novyy svit
# Processing Record 48 of Set 23 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 23 | yingkou
# Processing Record 50 of Set 23 | sao filipe
# Processing Record 1 of Set 24 | jiangyan
# Processing Record 2 of Set 24 | bani
# Processing Record 3 of Set 24 | umm lajj
# Processing Record 4 of Set 24 | chicama
# Processing Record 5 of Set 24 | kruisfontein
# Processing Record 6 of Set 24 | quarai
# Processing Record 7 of Set 24 | hailar
# Processing Record 8 of Set 24 | pathein
# Processing Record 9 of Set 24 | springbok
# Processing Record 10 of Set 24 | bereznik
# Processing Record 11 of Set 24 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 24 | sosnovo-ozerskoye
# Processing Record 13 of Set 24 | anito
# Processing Record 14 of Set 24 | opole
# Processing Record 15 of Set 24 | san andres
# Processing Record 16 of Set 24 | talcahuano
# Processing Record 17 of Set 24 | blama
# Processing Record 18 of Set 24 | fort frances
# Processing Record 19 of Set 24 | letlhakane
# Processing Record 20 of Set 24 | chapleau
# Processing Record 21 of Set 24 | kinkala
# Processing Record 22 of Set 24 | dingle
# Processing Record 23 of Set 24 | bonavista
# Processing Record 24 of Set 24 | mandalgovi
# Processing Record 25 of Set 24 | port hardy
# Processing Record 26 of Set 24 | bondoukou
# Processing Record 27 of Set 24 | dosso
# Processing Record 28 of Set 24 | dehui
# Processing Record 29 of Set 24 | pangkalanbuun
# Processing Record 30 of Set 24 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 24 | grado
# Processing Record 32 of Set 24 | praia
# Processing Record 33 of Set 24 | gamba
# Processing Record 34 of Set 24 | moron
# Processing Record 35 of Set 24 | nyurba
# Processing Record 36 of Set 24 | xai-xai
# Processing Record 37 of Set 24 | luban
# Processing Record 38 of Set 24 | kindu
# Processing Record 39 of Set 24 | magway
# Processing Record 40 of Set 24 | puerto suarez
# Processing Record 41 of Set 24 | porto novo
# Processing Record 42 of Set 24 | bubaque
# Processing Record 43 of Set 24 | zarumilla
# Processing Record 44 of Set 24 | namatanai
# Processing Record 45 of Set 24 | domoni
# Processing Record 46 of Set 24 | cayenne
# Processing Record 47 of Set 24 | alta floresta
# Processing Record 48 of Set 24 | boshnyakovo
# Processing Record 49 of Set 24 | ciudad guayana
# Processing Record 50 of Set 24 | gat
# Processing Record 1 of Set 25 | fallon
# Processing Record 2 of Set 25 | rabo de peixe
# Processing Record 3 of Set 25 | mana
# Processing Record 4 of Set 25 | yashkul
# Processing Record 5 of Set 25 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 25 | morondava
# Processing Record 7 of Set 25 | westport
# Processing Record 8 of Set 25 | takoradi
# Processing Record 9 of Set 25 | altay
# Processing Record 10 of Set 25 | sioux lookout
# Processing Record 11 of Set 25 | giulesti
# Processing Record 12 of Set 25 | paredon
# Processing Record 13 of Set 25 | lima
# Processing Record 14 of Set 25 | ponta delgada
# Processing Record 15 of Set 25 | birnin kebbi
# Processing Record 16 of Set 25 | sorland
# Processing Record 17 of Set 25 | espanola
# Processing Record 18 of Set 25 | noumea
# Processing Record 19 of Set 25 | duz
# City not found. Skipping...
# Processing Record 20 of Set 25 | rovaniemi
# Processing Record 21 of Set 25 | ughelli
# Processing Record 22 of Set 25 | mbanza-ngungu
# Processing Record 23 of Set 25 | iskateley
# Processing Record 24 of Set 25 | deputatskiy
# Processing Record 25 of Set 25 | strand
# Processing Record 26 of Set 25 | askiz
# Processing Record 27 of Set 25 | tsiroanomandidy
# Processing Record 28 of Set 25 | lac du bonnet
# Processing Record 29 of Set 25 | port macquarie
# Processing Record 30 of Set 25 | benghazi
# Processing Record 31 of Set 25 | ust-kuyga
# Processing Record 32 of Set 25 | fougamou
# Processing Record 33 of Set 25 | el retorno
# Processing Record 34 of Set 25 | touros
# Processing Record 35 of Set 25 | portland
# Processing Record 36 of Set 25 | ouesso
# Processing Record 37 of Set 25 | pangai
# Processing Record 38 of Set 25 | tura
# Processing Record 39 of Set 25 | maniitsoq
# Processing Record 40 of Set 25 | koulikoro
# Processing Record 41 of Set 25 | lasa
# Processing Record 42 of Set 25 | apollonia
# Processing Record 43 of Set 25 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 25 | honiara
# Processing Record 45 of Set 25 | ishurdi
# Processing Record 46 of Set 25 | flinders
# Processing Record 47 of Set 25 | bone
# Processing Record 48 of Set 25 | tocopilla
# Processing Record 49 of Set 25 | juba
# Processing Record 50 of Set 25 | casteltermini
# Processing Record 1 of Set 26 | homer
# Processing Record 2 of Set 26 | tutoia
# Processing Record 3 of Set 26 | rawson
# Processing Record 4 of Set 26 | leh
# Processing Record 5 of Set 26 | caravelas
# Processing Record 6 of Set 26 | springdale
# Processing Record 7 of Set 26 | pombia
# Processing Record 8 of Set 26 | geresk
# City not found. Skipping...
# Processing Record 9 of Set 26 | umbita
# Processing Record 10 of Set 26 | marzuq
# Processing Record 11 of Set 26 | oyama
# Processing Record 12 of Set 26 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 26 | manokwari
# Processing Record 14 of Set 26 | lincoln
# Processing Record 15 of Set 26 | ardabil
# Processing Record 16 of Set 26 | nome
# Processing Record 17 of Set 26 | kutum
# Processing Record 18 of Set 26 | rongcheng
# Processing Record 19 of Set 26 | channel-port aux basques
# Processing Record 20 of Set 26 | kiunga
# Processing Record 21 of Set 26 | mahibadhoo
# Processing Record 22 of Set 26 | dhidhdhoo
# Processing Record 23 of Set 26 | ugoofaaru
# Processing Record 24 of Set 26 | ibiruba
# Processing Record 25 of Set 26 | alvorada
# Processing Record 26 of Set 26 | huilong
# Processing Record 27 of Set 26 | yerbogachen
# Processing Record 28 of Set 26 | valjevo
# Processing Record 29 of Set 26 | brekstad
# Processing Record 30 of Set 26 | manyana
# Processing Record 31 of Set 26 | ust-tsilma
# Processing Record 32 of Set 26 | samarai
# Processing Record 33 of Set 26 | kuhdasht
# Processing Record 34 of Set 26 | lanzhou
# Processing Record 35 of Set 26 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 26 | kalangala
# Processing Record 37 of Set 26 | russell
# Processing Record 38 of Set 26 | san javier
# Processing Record 39 of Set 26 | khash
# Processing Record 40 of Set 26 | san borja
# Processing Record 41 of Set 26 | fortuna
# Processing Record 42 of Set 26 | high level
# Processing Record 43 of Set 26 | erzin
# Processing Record 44 of Set 26 | nantucket
# Processing Record 45 of Set 26 | nyuksenitsa
# Processing Record 46 of Set 26 | esfahan
# Processing Record 47 of Set 26 | gladstone
# Processing Record 48 of Set 26 | port arthur
# Processing Record 49 of Set 26 | fort nelson
# Processing Record 50 of Set 26 | mattru
# Processing Record 1 of Set 27 | el rosario
# Processing Record 2 of Set 27 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 27 | yiyang
# Processing Record 4 of Set 27 | gazimurskiy zavod
# Processing Record 5 of Set 27 | lensk
# Processing Record 6 of Set 27 | lom sak
# Processing Record 7 of Set 27 | pandan
# Processing Record 8 of Set 27 | weyburn
# Processing Record 9 of Set 27 | kamsack
# Processing Record 10 of Set 27 | talaya
# Processing Record 11 of Set 27 | nacala
# Processing Record 12 of Set 27 | natal
# Processing Record 13 of Set 27 | teguldet
# Processing Record 14 of Set 27 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 15 of Set 27 | karamay
# City not found. Skipping...
# Processing Record 16 of Set 27 | fukue
# Processing Record 17 of Set 27 | kahului
# Processing Record 18 of Set 27 | oksfjord
# Processing Record 19 of Set 27 | allonnes
# Processing Record 20 of Set 27 | oristano
# Processing Record 21 of Set 27 | camana
# Processing Record 22 of Set 27 | tarko-sale
# Processing Record 23 of Set 27 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 27 | la rioja
# Processing Record 25 of Set 27 | kribi
# Processing Record 26 of Set 27 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 27 | praia da vitoria
# Processing Record 28 of Set 27 | mogadishu
# Processing Record 29 of Set 27 | nelson bay
# Processing Record 30 of Set 27 | kuna
# Processing Record 31 of Set 27 | waingapu
# Processing Record 32 of Set 27 | tucurui
# Processing Record 33 of Set 27 | wukari
# Processing Record 34 of Set 27 | pouebo
# Processing Record 35 of Set 27 | paamiut
# Processing Record 36 of Set 27 | hauterive
# Processing Record 37 of Set 27 | montrose
# Processing Record 38 of Set 27 | kathmandu
# Processing Record 39 of Set 27 | birjand
# Processing Record 40 of Set 27 | mossendjo
# Processing Record 41 of Set 27 | kyra
# Processing Record 42 of Set 27 | bilokurakyne
# Processing Record 43 of Set 27 | tome
# Processing Record 44 of Set 27 | kaputa
# Processing Record 45 of Set 27 | evensk
# Processing Record 46 of Set 27 | colares
# Processing Record 47 of Set 27 | yeppoon
# Processing Record 48 of Set 27 | lorengau
# Processing Record 49 of Set 27 | bako
# Processing Record 50 of Set 27 | sampit
# Processing Record 1 of Set 28 | traralgon
# Processing Record 2 of Set 28 | nuevitas
# Processing Record 3 of Set 28 | balkhash
# Processing Record 4 of Set 28 | kaka
# Processing Record 5 of Set 28 | monforte de lemos
# Processing Record 6 of Set 28 | zhanatas
# City not found. Skipping...
# Processing Record 7 of Set 28 | molteno
# Processing Record 8 of Set 28 | bondowoso
# Processing Record 9 of Set 28 | catamarca
# Processing Record 10 of Set 28 | sinnamary
# Processing Record 11 of Set 28 | los llanos de aridane
# Processing Record 12 of Set 28 | mason city
# Processing Record 13 of Set 28 | myaundzha
# Processing Record 14 of Set 28 | ukiah
# Processing Record 15 of Set 28 | jutai
# Processing Record 16 of Set 28 | valparaiso
# Processing Record 17 of Set 28 | okha
# Processing Record 18 of Set 28 | concordia
# Processing Record 19 of Set 28 | kudahuvadhoo
# Processing Record 20 of Set 28 | kalmunai
# Processing Record 21 of Set 28 | sao felix do xingu
# Processing Record 22 of Set 28 | yining
# Processing Record 23 of Set 28 | sao jose da coroa grande
# Processing Record 24 of Set 28 | khorixas
# Processing Record 25 of Set 28 | aras
# Processing Record 26 of Set 28 | eldorado
# Processing Record 27 of Set 28 | solnechnyy
# Processing Record 28 of Set 28 | galbshtadt
# Processing Record 29 of Set 28 | machali
# Processing Record 30 of Set 28 | orbetello
# Processing Record 31 of Set 28 | siguiri
# Processing Record 32 of Set 28 | west bay
# Processing Record 33 of Set 28 | laukaa
# Processing Record 34 of Set 28 | sorong
# Processing Record 35 of Set 28 | bueu
# Processing Record 36 of Set 28 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 28 | bell ville
# Processing Record 38 of Set 28 | kuldur
# Processing Record 39 of Set 28 | eyl
# Processing Record 40 of Set 28 | sharjah
# Processing Record 41 of Set 28 | yaring
# Processing Record 42 of Set 28 | tombouctou
# Processing Record 43 of Set 28 | nanortalik
# Processing Record 44 of Set 28 | dakar
# Processing Record 45 of Set 28 | betioky
# Processing Record 46 of Set 28 | luwuk
# Processing Record 47 of Set 28 | diapaga
# Processing Record 48 of Set 28 | marshfield
# Processing Record 49 of Set 28 | bakchar
# Processing Record 50 of Set 28 | nelson
# Processing Record 1 of Set 29 | wanning
# Processing Record 2 of Set 29 | payakumbuh
# Processing Record 3 of Set 29 | jiayuguan
# Processing Record 4 of Set 29 | campbellton
# Processing Record 5 of Set 29 | rocha
# Processing Record 6 of Set 29 | boa vista
# Processing Record 7 of Set 29 | burica
# City not found. Skipping...
# Processing Record 8 of Set 29 | ternate
# Processing Record 9 of Set 29 | rayagada
# Processing Record 10 of Set 29 | san patricio
# Processing Record 11 of Set 29 | vila
# Processing Record 12 of Set 29 | rio grande
# Processing Record 13 of Set 29 | armacao de pera
# Processing Record 14 of Set 29 | shaunavon
# Processing Record 15 of Set 29 | bathurst
# Processing Record 16 of Set 29 | vastervik
# City not found. Skipping...
# Processing Record 17 of Set 29 | forestville
# Processing Record 18 of Set 29 | saint anthony
# Processing Record 19 of Set 29 | alofi
# Processing Record 20 of Set 29 | gornyy
# Processing Record 21 of Set 29 | batouri
# Processing Record 22 of Set 29 | malanje
# Processing Record 23 of Set 29 | san lawrenz
# Processing Record 24 of Set 29 | saint-georges
# Processing Record 25 of Set 29 | mamit
# Processing Record 26 of Set 29 | kommunisticheskiy
# Processing Record 27 of Set 29 | vila velha
# Processing Record 28 of Set 29 | berlevag
# Processing Record 29 of Set 29 | lukovetskiy
# Processing Record 30 of Set 29 | sahuayo
# City not found. Skipping...
# Processing Record 31 of Set 29 | smithers
# Processing Record 32 of Set 29 | itoman
# Processing Record 33 of Set 29 | ginda
# Processing Record 34 of Set 29 | fruitville
# Processing Record 35 of Set 29 | vostok
# Processing Record 36 of Set 29 | borlange
# City not found. Skipping...
# Processing Record 37 of Set 29 | shimoda
# Processing Record 38 of Set 29 | camopi
# Processing Record 39 of Set 29 | stolin
# Processing Record 40 of Set 29 | deep river
# Processing Record 41 of Set 29 | powell
# Processing Record 42 of Set 29 | lazaro cardenas
# Processing Record 43 of Set 29 | beian
# Processing Record 44 of Set 29 | santiago de cao
# Processing Record 45 of Set 29 | caohe
# Processing Record 46 of Set 29 | keti bandar
# Processing Record 47 of Set 29 | salamiyah
# Processing Record 48 of Set 29 | robertsport
# Processing Record 49 of Set 29 | contamana
# Processing Record 50 of Set 29 | nakhon thai
# Processing Record 1 of Set 30 | maykain
# City not found. Skipping...
# Processing Record 2 of Set 30 | sambava
# Processing Record 3 of Set 30 | tigzirt
# Processing Record 4 of Set 30 | san cosme y damian
# Processing Record 5 of Set 30 | port bannatyne
# Processing Record 6 of Set 30 | batala
# Processing Record 7 of Set 30 | koumac
# Processing Record 8 of Set 30 | sur
# Processing Record 9 of Set 30 | raurkela
# City not found. Skipping...
# Processing Record 10 of Set 30 | galle
# Processing Record 11 of Set 30 | powell river
# Processing Record 12 of Set 30 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 30 | darhan
# Processing Record 14 of Set 30 | pitanga
# Processing Record 15 of Set 30 | kalabo
# Processing Record 16 of Set 30 | montepuez
# Processing Record 17 of Set 30 | narodychi
# Processing Record 18 of Set 30 | anloga
# Processing Record 19 of Set 30 | goedereede
# Processing Record 20 of Set 30 | tual
# Processing Record 21 of Set 30 | leesburg
# Processing Record 22 of Set 30 | poshekhonye
# Processing Record 23 of Set 30 | zile
# Processing Record 24 of Set 30 | taltal
# Processing Record 25 of Set 30 | keningau
# Processing Record 26 of Set 30 | sakaiminato
# Processing Record 27 of Set 30 | harindanga
# Processing Record 28 of Set 30 | comodoro rivadavia
# Processing Record 29 of Set 30 | carira
# Processing Record 30 of Set 30 | sandomierz
# Processing Record 31 of Set 30 | koyilandi
# City not found. Skipping...
# Processing Record 32 of Set 30 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 33 of Set 30 | tiznit
# Processing Record 34 of Set 30 | tunduru
# City not found. Skipping...
# Processing Record 35 of Set 30 | mentakab
# Processing Record 36 of Set 30 | caxito
# Processing Record 37 of Set 30 | ligayan
# Processing Record 38 of Set 30 | rudnichnyy
# Processing Record 39 of Set 30 | elizabeth city
# Processing Record 40 of Set 30 | kabare
# Processing Record 41 of Set 30 | fuerte olimpo
# Processing Record 42 of Set 30 | sabang
# Processing Record 43 of Set 30 | aswan
# Processing Record 44 of Set 30 | oranjestad
# Processing Record 45 of Set 30 | makeni
# Processing Record 46 of Set 30 | elat
# Processing Record 47 of Set 30 | maragogi
# Processing Record 48 of Set 30 | musiri
# Processing Record 49 of Set 30 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 30 | campo verde
# Processing Record 1 of Set 31 | muriwai beach
# Processing Record 2 of Set 31 | jardim
# Processing Record 3 of Set 31 | levelland
# Processing Record 4 of Set 31 | naze
# Processing Record 5 of Set 31 | prainha
# Processing Record 6 of Set 31 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 31 | ardistan
# City not found. Skipping...
# Processing Record 8 of Set 31 | soligalich
# Processing Record 9 of Set 31 | ikom
# Processing Record 10 of Set 31 | vardo
# Processing Record 11 of Set 31 | mustafakemalpasa
# Processing Record 12 of Set 31 | snasa
# Processing Record 13 of Set 31 | minab
# Processing Record 14 of Set 31 | labuhan
# Processing Record 15 of Set 31 | manaure
# Processing Record 16 of Set 31 | shenzhen
# Processing Record 17 of Set 31 | lircay
# Processing Record 18 of Set 31 | okhotsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_dataredo)
# Out:
# 706

# %%
# Convert the array of dictionaries to a Panda DataFrame
city_data_df = pd.DataFrame(city_dataredo)
city_data_df.head(10)
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Busselton      AU  2022-07-23 01:48:58 -33.6500  115.3333     60.17
# 1    Fonte Boa      BR  2022-07-23 01:48:59  -2.4959  -66.2662     72.68
# 2     Matagami      CA  2022-07-23 01:48:59  49.7502  -77.6328     64.51
# 3      Zaoyang      CN  2022-07-23 01:49:00  32.1272  112.7542     79.02
# 4      Rikitea      PF  2022-07-23 01:49:00 -23.1203 -134.9692     72.59
# 5        Kapaa      US  2022-07-23 01:49:01  22.0752 -159.3190     84.52
# 6   Butaritari      KI  2022-07-23 01:49:01   3.0707  172.7902     81.99
# 7         Roma      US  2022-07-23 01:49:02  43.2128  -75.4557     72.82
# 8  Clyde River      CA  2022-07-23 01:49:02  70.4692  -68.5914     52.03
# 9   Bredasdorp      ZA  2022-07-23 01:49:02 -34.5322   20.0403     53.69
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        82         100       24.61          light rain
# 1        98         100        1.14     overcast clouds
# 2        77          75        9.22       broken clouds
# 3        73          92        4.54     overcast clouds
# 4        75          18        9.19          few clouds
# 5        65           0       14.97           clear sky
# 6        76         100        7.90     overcast clouds
# 7        83           4        2.89           clear sky
# 8        71          75       10.36       broken clouds
# 9        89          99        8.86          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Busselton      AU -33.6500  115.3333     60.17        82         100
# 1  Fonte Boa      BR  -2.4959  -66.2662     72.68        98         100
# 2   Matagami      CA  49.7502  -77.6328     64.51        77          75
# 3    Zaoyang      CN  32.1272  112.7542     79.02        73          92
# 4    Rikitea      PF -23.1203 -134.9692     72.59        75          18
#
#    Wind Speed Current Description
# 0       24.61          light rain
# 1        1.14     overcast clouds
# 2        9.22       broken clouds
# 3        4.54     overcast clouds
# 4        9.19          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
